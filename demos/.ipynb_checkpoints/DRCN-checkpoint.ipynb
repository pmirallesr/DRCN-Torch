# %% [markdown]
# ### Deep Reconstruction-Classification Networks for Unsupervised Domain Adaptation (DRCN) ###
#
# This code is an implementation in pytorch of the DRCN algorithm presented in [1], as applied to transferring results from SVHN to MNIST. A similar implementation exists at [2]. I have been unable to replicate Ghifary et al.'s results, but have reached results similar to [2]
#
# [1] M. Ghifary, W. B. Kleijn, M. Zhang, D. Balduzzi, and W. Li. "Deep Reconstruction-Classification Networks for Unsupervised Domain Adaptation (DRCN)", European Conference on Computer Vision (ECCV), 2016
#
# [2] https://github.com/fungtion/DRCN

# %% [markdown]
# First, clone the git repository to obtain the necessary modules

# %%
# !git clone https://github.com/pmirallesr/DRCN-Torch
# !cd DRCN-Torch

# %%
import sys, os
# Append .. = parent folder to path so that other package folders are visible
sys.path.append(os.path.abspath(os.path.join('..')))
print(sys.path)
# Out:
# ['/home/pmirallesr/Documents/DRCN-Torch/demos', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/home/pmirallesr/.local/lib/python3.8/site-packages', '/home/pmirallesr/Documents/gym-duckietown', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/home/pmirallesr/.local/lib/python3.8/site-packages/IPython/extensions', '/home/pmirallesr/.ipython', '/home/pmirallesr/Documents/DRCN-Torch', '/home/pmirallesr/Documents/DRCN-Torch']

# %% [markdown]
# ## INITIALIZATION ##

# %%
# Imports
import matplotlib.pyplot as plt
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import math
import time # To time performance
from itertools import product
from data.data_transforms import ImpulseDenoising, GaussianDenoising
import methods.learners.DRCN as DRCN
from utils.utils import setSeeds, imshow, calcExperimentsAmount, create_zip_name, weights_init


import tensorflow as tf # Good for logging experiments
import datetime # Good for naming stuff
from torchsummary import summary # Good for understanding our network

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %% [markdown]
# ## Hyperparameters ##
# use the dictionary experimentRanges to define series of experiments to be run
# lossControlPenalty is the lambda parameter in the original DRCN paper and trades-off autoencoder loss vs labeller loss.

# %%
# Hyperparameters
nbEpochs = 50
train_batch_size = 64
test_batch_size = 64

dropoutChance = 0.5
# denseLayerNeurons = 1024
# lossControlPenalty = 0.7 # controlPenalty = 0.4...0.7
sourceDataset = "SVHN"
targetDataset = "MNIST"
optimizerName = "RMSProp" #Adam or RMSProp
sourceChannels = 3

# experimentRanges[variable] = [val1, val2] sets up an experiment with val1, val 2.
# All cross combination possibilities of experiment ranges will be used.
# variable = valX sets the variable to that value instead, no experimenting.
# They may both be used simulatenously, but experimentRanges[var] overrides var
# The total number of experiments is product(len(experimentRanges[var])) over all vars
# in experimentRanges, or 1 if experimentRanges is empty.
# experimentRanges[var] = val1 and var = val1 are functionally dentical statements
experimentRanges = {}
experimentRanges["lossControlPenalty"] = [0.7]
experimentRanges["denseLayerNeurons"] = [1024]

alpha = 0.9 #Only relevant for RMSProp, smoothing constant for weight update
base_learningRate = 5e-6
experimentRanges["learningRate"] = [1e-4]
experimentRanges["weight_decay"] = [5e-6]

dataPath = os.path.dirname(os.getcwd()) + "/data/"
log_dir = os.path.dirname(os.getcwd()) + "/logs/"

randomSeed = 1905

# %%
# Sets all seeds to the chosen number
setSeeds(randomSeed) 
# Creates the logging directory
os.makedirs(log_dir, exist_ok = True)
f = open(log_dir + "experimentRanges.txt", 'w')
f.write(str(experimentRanges))
f.close()

# %% [markdown]
# ## DATA LOADING ##
#
# We apply several transformations to both MNIST and SVHN
#
# Both datasets are augmented with random rotations of 20 degrees. The original paper also called for random translations of 20% of the image's width, and randomly dropping pixels of each image with a 50% chance per pixel (Impulse noise)
#
# Additionally SVHN is grayscaled and MNIST is rescaled to 32x32 pixels through a bilinear interpolation

# %%
# Data Transforms

# image data augments are performed on all images before they're transformed to tensors
# tensor data augments are performed on all images after they're transformed to tensors
# MNIST / SVHN transforms are performed only on MNIST / SVHN data, and include a toTensor transformation

# Data Augmentation - Geometric Transformations
# 20º random rotation
# 20% random height and width shifts
imageDataAugmentTransforms = []
# imageDataAugmentTransforms.append(torchvision.transforms.RandomAffine(degrees = 20))
#imageDataAugmentTransforms.append(torchvision.transforms.RandomAffine(degrees = 20, translate = (0.2, 0.2)))

# Denoising
tensorDataAugmentTransforms = []
# tensorDataAugmentTransforms.append(ImpulseDenoising())
# tensorDataAugmentTransforms.append(GaussianDenoising(0.2, multiplicative))


MNIST_Transforms = []
MNIST_Transforms.append(torchvision.transforms.Resize((32,32), interpolation = 2)) #Rescale to SVHN size
MNIST_Transforms.append(torchvision.transforms.ToTensor())

SVHN_Transforms = []
# SVHN_Transforms.append(torchvision.transforms.Grayscale())
SVHN_Transforms.append(torchvision.transforms.ToTensor())

# %%
# Create the data loaders

train_MNIST_loader = torch.utils.data.DataLoader \
                (torchvision.datasets.MNIST(dataPath, \
                train = True, download = True, \
                transform = torchvision.transforms.Compose\
                (imageDataAugmentTransforms + MNIST_Transforms + tensorDataAugmentTransforms)), batch_size = train_batch_size, shuffle = True)

test_MNIST_loader = torch.utils.data.DataLoader \
                (torchvision.datasets.MNIST(dataPath, \
                train = False, download = True, \
                transform = torchvision.transforms.Compose\
                (MNIST_Transforms)), batch_size = test_batch_size, shuffle = True)

#DataLoader has irregular behaviour, does not autom create an SVHN folder but does so for MNIST
train_SVHN_loader = torch.utils.data.DataLoader \
                (torchvision.datasets.SVHN(dataPath + "SVHN/", \
                split = "train", download = True, \
                transform = torchvision.transforms.Compose\
                (imageDataAugmentTransforms + SVHN_Transforms + tensorDataAugmentTransforms)), batch_size = train_batch_size, shuffle = True)

test_SVHN_loader = torch.utils.data.DataLoader \
                (torchvision.datasets.SVHN(dataPath + "SVHN/", \
                split = "test", download = True , \
                 transform = torchvision.transforms.Compose \
                (SVHN_Transforms)), batch_size = test_batch_size, shuffle = True)
# Out:
# Using downloaded and verified file: /home/pmirallesr/Documents/DRCN-Torch/data/SVHN/train_32x32.mat
# Using downloaded and verified file: /home/pmirallesr/Documents/DRCN-Torch/data/SVHN/test_32x32.mat

# %% [markdown]
# We show an example batch of both source and target to check the transforms applied

# %%
# get some random training images from source
batch_id, (images, labels) = next(enumerate(train_SVHN_loader))
print('Source Domain batch')
imshow(torchvision.utils.make_grid(images))

# get some random training images from target
batch_id, (images, labels) = next(enumerate(train_MNIST_loader))
print('Target Domain batch')
imshow(torchvision.utils.make_grid(images))
# Out:
# Source Domain batch
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-42c2a828666e> in <module>
#       2 batch_id, (images, labels) = next(enumerate(train_SVHN_loader))
#       3 print('Source Domain batch')
# ----> 4 imshow(torchvision.utils.make_grid(images))
#       5
#       6 # get some random training images from target
#
# ~/Documents/DRCN-Torch/utils/utils.py in imshow(img)
#      16     npimg = img.numpy()
#      17     plt.rcParams["figure.figsize"] = [16,9]
# ---> 18     plt.imshow(np.transpose(npimg, (1, 2, 0)))
#      19     plt.show()
#      20
#
# AttributeError: module 'matplotlib' has no attribute 'imshow'

# %%
def getSettings():
  settings = {}
  settings["optimizer"] = optimizerName
  settings["learningRate"] = learningRate
  if(optimizerName == "RMSProp"):
    settings["weight_decay"] = weight_decay
    settings["alpha"] = alpha
  settings["Epochs"] = nbEpochs
  settings["train_batch_size"] = train_batch_size
  settings["test_batch_size"] = test_batch_size
  settings["dropoutChance"] = dropoutChance
  settings["denseLayerNeurons"] = denseLayerNeurons
  settings["lossControlPenalty"] = lossControlPenalty
  settings["randomSeed"] = randomSeed
  return settings

# %% [markdown]
# ## DRCN ##
#
# The architecture of DRCN is simple: An autoencoder and a convolutional labeller with a common encoder body. We alternatively train the autoencoder to reconstruct inputs from the target domain and the labeller to label inputs from the source domain. The network slowly becomes better at both tasks, sacrificing some labelling performance in exchange for some reconstruction performance.
#
# We then take the labeller, trained on the source domain, and apply it to the target domain.

# %%
# Create experiments from expRanges configuration dict
experiments = product(*list(experimentRanges.values()), repeat=1)
#Experiments to be run
totalExp = calcExperimentsAmount(experimentRanges)
start_at_exp = 1 # Controls experiments to be ignored
nExp = 0 #experiment counter
# Run all the experiments
for experimentParams in experiments:
    nExp += 1
    if(nExp < start_at_exp): # Skip already done experiments
        continue
    # Assign and print this experiment's parameters
    for n in range(len(experimentParams)):
        paramName = list(experimentRanges.keys())[n]
        exec("%s = %f" % (paramName, experimentParams[n])) #Paramname = experimentParams[n]
        print("{}: {}".format(paramName, experimentParams[n]))
    
    #Run this experiment
    
    # Create network
    encoder = Encoder(sourceChannels, dropoutChance = dropoutChance, denseLayerNeurons = int(denseLayerNeurons)).to(device)
    labeller = Labeller(encoder).to(device)
    autoencoder = Autoencoder(encoder).to(device)
    # Custom initialize for conv layers
    autoencoder.apply(weights_init).to(device)
    
    # Print network summary
    _, (example, _) = next(enumerate(train_SVHN_loader))
    summary(labeller, example.shape[1:])
    summary(autoencoder, example.shape[1:])
    
    # Init optimizer
    if(optimizerName == "Adam"):
      labeller_optimizer = torch.optim.Adam(labeller.parameters(), lr = 3*learningRate)
      autoencoder_optimizer = torch.optim.Adam(autoencoder.parameters(), lr = 3*learningRate)
    elif(optimizerName == "RMSProp"):
      labeller_optimizer = torch.optim.RMSprop(labeller.parameters(), lr=learningRate, weight_decay=weight_decay, alpha = alpha)
      autoencoder_optimizer = torch.optim.RMSprop(autoencoder.parameters(), lr=learningRate, weight_decay=weight_decay, alpha = alpha)
    # Init loss criteria
    labellerCriterion = nn.CrossEntropyLoss()
    autoencoderCriterion = nn.MSELoss()
    
    # Create tensorboard log folder
    log_dir = os.path.dirname(os.getcwd()) + \
                "/logs/" "{}-{}, ".format(sourceDataset, targetDataset) + \
                "experiment parameters: {}, ".format(experimentParams) + \
                "{} epochs.".format(nbEpochs) + \
                datetime.datetime.now().strftime("Date - %Y%m%d-%H%M")
    os.makedirs(log_dir, exist_ok = True)
    
    # Write settings log
    f = open(log_dir + "/settings.txt", 'w')
    f.write(str(getSettings()))
    f.close()
    
    # Set train modes
    encoder.train()
    labeller.train()
    autoencoder.train()
    
    # To keep track of performance during eval
    bestTargetAccuracy = 0
    bestSourceAccuracy = 0
    prev_source_train_accuracy = 0
    prev_source_test_accuracy = 0
    prev_target_train_accuracy = 0
    prev_target_test_accuracy = 0
    
    # To keep timing
    avgEpochTime = 0
    start = time.time()
    # Verbosity controls
    batchesVerbosity = 50
    
    # More variables for printing advancement and tensorboard
    SVHNBatches = int(73300/train_batch_size) #SVHN size
    MNISTBatches = int(60000/train_batch_size) #MNIST size
    train_summary_writer = tf.summary.create_file_writer(log_dir)
    test_summary_writer = tf.summary.create_file_writer(log_dir)
    
    # The nets are evaluated every N periods
    validationPeriod = 5

    #Start training
    print("Training for {} epochs. Batch size {}, {} and {} batches per epoch of source and target respectively".format(nbEpochs, train_batch_size, SVHNBatches, MNISTBatches))
    for epoch in range(1, nbEpochs + 1):
        if ((epoch%validationPeriod == 0) or (epoch < validationPeriod)):
            labeller.eval()
            # Start with a t=0 validation run
            print("Validation run")
            print("--------------")
            with torch.no_grad():
                # Log source train accuracy
                (_, _, source_train_accuracy) = getLabellingAccuracy(train_SVHN_loader, labeller)
                print("Accuracy (Train) on SVHN: {:2.2f}%, {:+2.2f}%".format(source_train_accuracy, source_train_accuracy - prev_source_train_accuracy))
                with train_summary_writer.as_default():
                    tf.summary.scalar('Source_train_accuracy', source_train_accuracy, epoch)
                prev_source_train_accuracy = source_train_accuracy
                # Log source test accuracy
                (_, _, source_test_accuracy) = getLabellingAccuracy(test_SVHN_loader, labeller)        
                print("Accuracy (Test) on SVHN: {:2.2f}%, {:+2.2f}%".format(source_test_accuracy, source_test_accuracy - prev_source_test_accuracy))
                print("{:+2.2f}% with respect to maximum of {:2.2f}%".format(source_test_accuracy - bestSourceAccuracy, bestSourceAccuracy)) 
                if source_test_accuracy > bestSourceAccuracy:
                    print("Best accuracy on source so far!")
                    bestSourceAccuracy = source_test_accuracy
                    # bestSourceAccuracySettings = getSettings()
                with test_summary_writer.as_default():
                    tf.summary.scalar('Source_test_accuracy', source_test_accuracy, epoch)
                prev_source_test_accuracy = source_test_accuracy
                # # Log target train accuracy
                # (_, _, target_train_accuracy) = getLabellingAccuracy(train_MNIST_loader, labeller)
                # print("Accuracy (Train) on MNIST: {:2.2f}%, {:+2.2f}%".format(target_train_accuracy, target_train_accuracy - prev_target_train_accuracy)) 
                # with train_summary_writer.as_default():
                #     tf.summary.scalar('Target_train_accuracy', target_train_accuracy, epoch)
                # prev_target_train_accuracy = target_train_accuracy
                # # Log target test accuracy
                # (_, _, target_test_accuracy) = getLabellingAccuracy(test_MNIST_loader, labeller)
                # print("Accuracy (Test) on MNIST: {:2.2f}%, {:+2.2f}%".format(target_test_accuracy, target_test_accuracy - prev_target_test_accuracy))  
                # print("{:+2.2f}% gap with respect to maximum of {:2.2f}%".format(target_test_accuracy - bestTargetAccuracy, bestTargetAccuracy)) 
                # if target_test_accuracy > bestTargetAccuracy:
                #     print("Best accuracy on target so far!")
                #     bestTargetAccuracy = target_test_accuracy
                #     # bestTargetAccuracySettings = getSettings()
                # with test_summary_writer.as_default():
                #     tf.summary.scalar('Target_test_accuracy', target_test_accuracy, epoch)
                # prev_target_test_accuracy = target_test_accuracy

            labeller.train()
        print("--------------")

        # Timekeeping
        epochStart = time.time()
        
        # Train on target dataset
        # print("Target")
        # for batch_id, (data, target) in enumerate(train_MNIST_loader):
        #     autoencoder_optimizer.zero_grad()
        #     autoencoder.zero_grad()
        #     encoder.zero_grad()
        #     data = data.to(device)
        #     target = target.to(device)
        #     forward = autoencoder(data)
        #     data = torch.tensor(data, dtype = torch.double, requires_grad=True).to(device)
        #     autoencoderLoss = autoencoderCriterion(forward, data)
        #     autoencoderLoss *= (1 - lossControlPenalty)
        #
        #     # Log performance to tensorboard  
        #     with train_summary_writer.as_default():
        #         index = epoch*MNISTBatches + batch_id
        #         tf.summary.scalar('Autoencoder_Loss', autoencoderLoss.item(), index)
        #     if(batch_id%batchesVerbosity == 0):
        #         print("Target batch {}, epoch {}. Loss = {:.5f}".format(batch_id, epoch, autoencoderLoss.item()))           
        #     autoencoderLoss.backward()
        #     autoencoder_optimizer.step()

        # Train on source dataset
        print("Source")
        for batch_id, (data, target) in enumerate(train_SVHN_loader):
            labeller_optimizer.zero_grad()
            labeller.zero_grad()
            encoder.zero_grad()
            data = data.to(device)
            target = target.to(device)
            forward = labeller(data).to(device)
            labellerLoss = labellerCriterion(forward, target)
            labellerLoss *= lossControlPenalty # Apply the loss control penalty
            
            # Log performance to tensorboard
            with train_summary_writer.as_default():
                index = epoch*SVHNBatches + batch_id
                tf.summary.scalar('Labeller Loss', labellerLoss.item(), index)
            if(batch_id%batchesVerbosity == 0):
                print("Source batch {}, epoch {}. Loss = {:.5f}".format(batch_id, epoch, labellerLoss.item()))
            labellerLoss.backward()
            labeller_optimizer.step()
        
        # Timekeeping and print advancement
        epochEnd = time.time()
        avgEpochTime = (avgEpochTime*(epoch-1) + (epochEnd - epochStart)) / epoch
        print("--------------")
        print("Experiment: {}/{}".format(nExp,totalExp))
        print("Epoch {}/{} completed in {:.5f} minutes".format(epoch, nbEpochs, (epochEnd - epochStart)/60))
        print("{:.3f} minutes elapsed".format((epochEnd - start)/60))
        print("{:.2f} minutes remaining".format(avgEpochTime/60 * (nbEpochs - epoch)))
        print("--------------")

        
print("DONE!")
# Out:
# lossControlPenalty: 0.7
# denseLayerNeurons: 1024
# learningRate: 0.0001
# weight_decay: 5e-06
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 100, 32, 32]           7,600
#          MaxPool2d-2          [-1, 100, 16, 16]               0
#             Conv2d-3          [-1, 150, 16, 16]         375,150
#          MaxPool2d-4            [-1, 150, 8, 8]               0
#             Conv2d-5            [-1, 200, 8, 8]         270,200
#             Linear-6                 [-1, 1024]      13,108,224
#          Dropout2d-7                 [-1, 1024]               0
#             Linear-8                 [-1, 1024]       1,049,600
#          Dropout2d-9                 [-1, 1024]               0
#           Encoder-10                 [-1, 1024]               0
#            Linear-11                   [-1, 10]          10,250
# ================================================================
# Total params: 14,821,024
# Trainable params: 14,821,024
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.48
# Params size (MB): 56.54
# Estimated Total Size (MB): 58.03
# ----------------------------------------------------------------
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 100, 32, 32]           7,600
#          MaxPool2d-2          [-1, 100, 16, 16]               0
#             Conv2d-3          [-1, 150, 16, 16]         375,150
#          MaxPool2d-4            [-1, 150, 8, 8]               0
#             Conv2d-5            [-1, 200, 8, 8]         270,200
#             Linear-6                 [-1, 1024]      13,108,224
#          Dropout2d-7                 [-1, 1024]               0
#             Linear-8                 [-1, 1024]       1,049,600
#          Dropout2d-9                 [-1, 1024]               0
#           Encoder-10                 [-1, 1024]               0
#            Linear-11                 [-1, 1024]       1,049,600
#            Linear-12                [-1, 12800]      13,120,000
#            Conv2d-13            [-1, 200, 8, 8]         360,200
#            Conv2d-14            [-1, 150, 8, 8]         270,150
#          Upsample-15          [-1, 150, 16, 16]               0
#            Conv2d-16          [-1, 100, 16, 16]         375,100
#          Upsample-17          [-1, 100, 32, 32]               0
#            Conv2d-18            [-1, 3, 32, 32]           7,503
# ================================================================
# Total params: 29,993,327
# Trainable params: 29,993,327
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.05
# Params size (MB): 114.42
# Estimated Total Size (MB): 117.48
# ----------------------------------------------------------------
# Training for 50 epochs. Batch size 64, 1145 and 937 batches per epoch of source and target respectively
# Validation run
# --------------
# Accuracy (Train) on SVHN: 6.89%, +6.89%
# Accuracy (Test) on SVHN: 6.38%, +6.38%
# +6.38% with respect to maximum of 0.00%
# Best accuracy on source so far!
# --------------
# Source
# Source batch 0, epoch 1. Loss = 1.61447
# Source batch 50, epoch 1. Loss = 1.54824
# Source batch 100, epoch 1. Loss = 1.53380
# Source batch 150, epoch 1. Loss = 1.54107
# Source batch 200, epoch 1. Loss = 1.59582
# Source batch 250, epoch 1. Loss = 1.52242
# Source batch 300, epoch 1. Loss = 1.47685
# Source batch 350, epoch 1. Loss = 1.53570
# Source batch 400, epoch 1. Loss = 1.49514
# Source batch 450, epoch 1. Loss = 1.48326
# Source batch 500, epoch 1. Loss = 1.32111
# Source batch 550, epoch 1. Loss = 1.26505
# Source batch 600, epoch 1. Loss = 1.23521
# Source batch 650, epoch 1. Loss = 1.22070
# Source batch 700, epoch 1. Loss = 1.21920
# Source batch 750, epoch 1. Loss = 1.27188
# Source batch 800, epoch 1. Loss = 1.14107
# Source batch 850, epoch 1. Loss = 0.90385
# Source batch 900, epoch 1. Loss = 0.97260
# Source batch 950, epoch 1. Loss = 0.85728
# Source batch 1000, epoch 1. Loss = 0.63748
# Source batch 1050, epoch 1. Loss = 0.83026
# Source batch 1100, epoch 1. Loss = 0.62823
# --------------
# Experiment: 1/1
# Epoch 1/50 completed in 0.36828 minutes
# 0.747 minutes elapsed
# 18.05 minutes remaining
# --------------
# Validation run
# --------------
# Accuracy (Train) on SVHN: 73.80%, +66.92%
# Accuracy (Test) on SVHN: 73.54%, +67.16%
# +67.16% with respect to maximum of 6.38%
# Best accuracy on source so far!
# --------------
# Source
# Source batch 0, epoch 2. Loss = 0.51427
# Source batch 50, epoch 2. Loss = 0.67976
# Source batch 100, epoch 2. Loss = 0.79902
# Source batch 150, epoch 2. Loss = 0.57961
# Source batch 200, epoch 2. Loss = 0.43564
# Source batch 250, epoch 2. Loss = 0.54173
# Source batch 300, epoch 2. Loss = 0.64368
# Source batch 350, epoch 2. Loss = 0.45700
# Source batch 400, epoch 2. Loss = 0.31822
# Source batch 450, epoch 2. Loss = 0.44688
# Source batch 500, epoch 2. Loss = 0.54058
# Source batch 550, epoch 2. Loss = 0.27056
# Source batch 600, epoch 2. Loss = 0.54739
# Source batch 650, epoch 2. Loss = 0.58969
# Source batch 700, epoch 2. Loss = 0.40116
# Source batch 750, epoch 2. Loss = 0.30979
# Source batch 800, epoch 2. Loss = 0.61820
# Source batch 850, epoch 2. Loss = 0.38277
# Source batch 900, epoch 2. Loss = 0.42768
# Source batch 950, epoch 2. Loss = 0.38751
# Source batch 1000, epoch 2. Loss = 0.32588
# Source batch 1050, epoch 2. Loss = 0.50136
# Source batch 1100, epoch 2. Loss = 0.47396
# --------------
# Experiment: 1/1
# Epoch 2/50 completed in 0.36658 minutes
# 1.490 minutes elapsed
# 17.64 minutes remaining
# --------------
# Validation run
# --------------
# Accuracy (Train) on SVHN: 85.97%, +12.17%
# Accuracy (Test) on SVHN: 85.18%, +11.64%
# +11.64% with respect to maximum of 73.54%
# Best accuracy on source so far!
# --------------
# Source
# Source batch 0, epoch 3. Loss = 0.29342
# Source batch 50, epoch 3. Loss = 0.30419
# Source batch 100, epoch 3. Loss = 0.28346
# Source batch 150, epoch 3. Loss = 0.30389
# Source batch 200, epoch 3. Loss = 0.35635
# Source batch 250, epoch 3. Loss = 0.33840
# Source batch 300, epoch 3. Loss = 0.29994
# Source batch 350, epoch 3. Loss = 0.26759
# Source batch 400, epoch 3. Loss = 0.29301
# Source batch 450, epoch 3. Loss = 0.36962
# Source batch 500, epoch 3. Loss = 0.27616
# Source batch 550, epoch 3. Loss = 0.38671
# Source batch 600, epoch 3. Loss = 0.35492
# Source batch 650, epoch 3. Loss = 0.41169
# Source batch 700, epoch 3. Loss = 0.24429
# Source batch 750, epoch 3. Loss = 0.31852
# Source batch 800, epoch 3. Loss = 0.31053
# Source batch 850, epoch 3. Loss = 0.36135
# Source batch 900, epoch 3. Loss = 0.23423
# Source batch 950, epoch 3. Loss = 0.21475
# Source batch 1000, epoch 3. Loss = 0.33391
# Source batch 1050, epoch 3. Loss = 0.27042
# Source batch 1100, epoch 3. Loss = 0.32119
# --------------
# Experiment: 1/1
# Epoch 3/50 completed in 0.36880 minutes
# 2.232 minutes elapsed
# 17.29 minutes remaining
# --------------
# Validation run
# --------------
# Accuracy (Train) on SVHN: 89.30%, +3.33%
# Accuracy (Test) on SVHN: 88.08%, +2.90%
# +2.90% with respect to maximum of 85.18%
# Best accuracy on source so far!
# --------------
# Source
# Source batch 0, epoch 4. Loss = 0.15137
# Source batch 50, epoch 4. Loss = 0.26775
# Source batch 100, epoch 4. Loss = 0.35419
# Source batch 150, epoch 4. Loss = 0.32171
# Source batch 200, epoch 4. Loss = 0.43555
# Source batch 250, epoch 4. Loss = 0.34191
# Source batch 300, epoch 4. Loss = 0.15734
# Source batch 350, epoch 4. Loss = 0.15848
# Source batch 400, epoch 4. Loss = 0.19047
# Source batch 450, epoch 4. Loss = 0.34058
# Source batch 500, epoch 4. Loss = 0.30177
# Source batch 550, epoch 4. Loss = 0.41125
# Source batch 600, epoch 4. Loss = 0.20503
# Source batch 650, epoch 4. Loss = 0.22319
# Source batch 700, epoch 4. Loss = 0.12422
# Source batch 750, epoch 4. Loss = 0.14041
# Source batch 800, epoch 4. Loss = 0.33255
# Source batch 850, epoch 4. Loss = 0.29084
# Source batch 900, epoch 4. Loss = 0.20817
# Source batch 950, epoch 4. Loss = 0.21483
# Source batch 1000, epoch 4. Loss = 0.22598
# Source batch 1050, epoch 4. Loss = 0.24450
# Source batch 1100, epoch 4. Loss = 0.17400
# --------------
# Experiment: 1/1
# Epoch 4/50 completed in 0.36596 minutes
# 2.973 minutes elapsed
# 16.90 minutes remaining
# --------------
# Validation run
# --------------
# Accuracy (Train) on SVHN: 91.13%, +1.83%
# Accuracy (Test) on SVHN: 88.96%, +0.88%
# +0.88% with respect to maximum of 88.08%
# Best accuracy on source so far!
# --------------
# Source
# Source batch 0, epoch 5. Loss = 0.17972
# Source batch 50, epoch 5. Loss = 0.30201
# Source batch 100, epoch 5. Loss = 0.27960
# Source batch 150, epoch 5. Loss = 0.29183
# Source batch 200, epoch 5. Loss = 0.19634
# Source batch 250, epoch 5. Loss = 0.18408
# Source batch 300, epoch 5. Loss = 0.26939
# Source batch 350, epoch 5. Loss = 0.36813
# Source batch 400, epoch 5. Loss = 0.24071
# Source batch 450, epoch 5. Loss = 0.11147
# Source batch 500, epoch 5. Loss = 0.26773
# Source batch 550, epoch 5. Loss = 0.19528
# Source batch 600, epoch 5. Loss = 0.36978
# Source batch 650, epoch 5. Loss = 0.24875
# Source batch 700, epoch 5. Loss = 0.25174
# Source batch 750, epoch 5. Loss = 0.23897
# Source batch 800, epoch 5. Loss = 0.28464
# Source batch 850, epoch 5. Loss = 0.26724
# Source batch 900, epoch 5. Loss = 0.02898
# Source batch 950, epoch 5. Loss = 0.37467
# Source batch 1000, epoch 5. Loss = 0.27060
# Source batch 1050, epoch 5. Loss = 0.42216
# Source batch 1100, epoch 5. Loss = 0.38525
# --------------
# Experiment: 1/1
# Epoch 5/50 completed in 0.36853 minutes
# 3.716 minutes elapsed
# 16.54 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 6. Loss = 0.19488
# Source batch 50, epoch 6. Loss = 0.32710
# Source batch 100, epoch 6. Loss = 0.22812
# Source batch 150, epoch 6. Loss = 0.24593
# Source batch 200, epoch 6. Loss = 0.26678
# Source batch 250, epoch 6. Loss = 0.20448
# Source batch 300, epoch 6. Loss = 0.27526
# Source batch 350, epoch 6. Loss = 0.26245
# Source batch 400, epoch 6. Loss = 0.28625
# Source batch 450, epoch 6. Loss = 0.40400
# Source batch 500, epoch 6. Loss = 0.15818
# Source batch 550, epoch 6. Loss = 0.11530
# Source batch 600, epoch 6. Loss = 0.34481
# Source batch 650, epoch 6. Loss = 0.15722
# Source batch 700, epoch 6. Loss = 0.31695
# Source batch 750, epoch 6. Loss = 0.11245
# Source batch 800, epoch 6. Loss = 0.22826
# Source batch 850, epoch 6. Loss = 0.17971
# Source batch 900, epoch 6. Loss = 0.29696
# Source batch 950, epoch 6. Loss = 0.16009
# Source batch 1000, epoch 6. Loss = 0.18641
# Source batch 1050, epoch 6. Loss = 0.18907
# Source batch 1100, epoch 6. Loss = 0.40316
# --------------
# Experiment: 1/1
# Epoch 6/50 completed in 0.36444 minutes
# 4.080 minutes elapsed
# 16.15 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 7. Loss = 0.34497
# Source batch 50, epoch 7. Loss = 0.12309
# Source batch 100, epoch 7. Loss = 0.19131
# Source batch 150, epoch 7. Loss = 0.13494
# Source batch 200, epoch 7. Loss = 0.15424
# Source batch 250, epoch 7. Loss = 0.17847
# Source batch 300, epoch 7. Loss = 0.18288
# Source batch 350, epoch 7. Loss = 0.14623
# Source batch 400, epoch 7. Loss = 0.16124
# Source batch 450, epoch 7. Loss = 0.32150
# Source batch 500, epoch 7. Loss = 0.27580
# Source batch 550, epoch 7. Loss = 0.12376
# Source batch 600, epoch 7. Loss = 0.22958
# Source batch 650, epoch 7. Loss = 0.18986
# Source batch 700, epoch 7. Loss = 0.20614
# Source batch 750, epoch 7. Loss = 0.22634
# Source batch 800, epoch 7. Loss = 0.22689
# Source batch 850, epoch 7. Loss = 0.16374
# Source batch 900, epoch 7. Loss = 0.17694
# Source batch 950, epoch 7. Loss = 0.15631
# Source batch 1000, epoch 7. Loss = 0.27464
# Source batch 1050, epoch 7. Loss = 0.14545
# Source batch 1100, epoch 7. Loss = 0.15511
# --------------
# Experiment: 1/1
# Epoch 7/50 completed in 0.36384 minutes
# 4.444 minutes elapsed
# 15.77 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 8. Loss = 0.29760
# Source batch 50, epoch 8. Loss = 0.12387
# Source batch 100, epoch 8. Loss = 0.33509
# Source batch 150, epoch 8. Loss = 0.33453
# Source batch 200, epoch 8. Loss = 0.14000
# Source batch 250, epoch 8. Loss = 0.23193
# Source batch 300, epoch 8. Loss = 0.13654
# Source batch 350, epoch 8. Loss = 0.24393
# Source batch 400, epoch 8. Loss = 0.14945
# Source batch 450, epoch 8. Loss = 0.06149
# Source batch 500, epoch 8. Loss = 0.17526
# Source batch 550, epoch 8. Loss = 0.37927
# Source batch 600, epoch 8. Loss = 0.16408
# Source batch 650, epoch 8. Loss = 0.19836
# Source batch 700, epoch 8. Loss = 0.15407
# Source batch 750, epoch 8. Loss = 0.16213
# Source batch 800, epoch 8. Loss = 0.20465
# Source batch 850, epoch 8. Loss = 0.23775
# Source batch 900, epoch 8. Loss = 0.36005
# Source batch 950, epoch 8. Loss = 0.29160
# Source batch 1000, epoch 8. Loss = 0.14141
# Source batch 1050, epoch 8. Loss = 0.13805
# Source batch 1100, epoch 8. Loss = 0.21826
# --------------
# Experiment: 1/1
# Epoch 8/50 completed in 0.36508 minutes
# 4.809 minutes elapsed
# 15.39 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 9. Loss = 0.10208
# Source batch 50, epoch 9. Loss = 0.36216
# Source batch 100, epoch 9. Loss = 0.16433
# Source batch 150, epoch 9. Loss = 0.21900
# Source batch 200, epoch 9. Loss = 0.14720
# Source batch 250, epoch 9. Loss = 0.15865
# Source batch 300, epoch 9. Loss = 0.09214
# Source batch 350, epoch 9. Loss = 0.13902
# Source batch 400, epoch 9. Loss = 0.19151
# Source batch 450, epoch 9. Loss = 0.28130
# Source batch 500, epoch 9. Loss = 0.15484
# Source batch 550, epoch 9. Loss = 0.13266
# Source batch 600, epoch 9. Loss = 0.17768
# Source batch 650, epoch 9. Loss = 0.17563
# Source batch 700, epoch 9. Loss = 0.22567
# Source batch 750, epoch 9. Loss = 0.17525
# Source batch 800, epoch 9. Loss = 0.19075
# Source batch 850, epoch 9. Loss = 0.19613
# Source batch 900, epoch 9. Loss = 0.19453
# Source batch 950, epoch 9. Loss = 0.16227
# Source batch 1000, epoch 9. Loss = 0.17623
# Source batch 1050, epoch 9. Loss = 0.26284
# Source batch 1100, epoch 9. Loss = 0.15652
# --------------
# Experiment: 1/1
# Epoch 9/50 completed in 0.36468 minutes
# 5.174 minutes elapsed
# 15.02 minutes remaining
# --------------
# Validation run
# --------------
# Accuracy (Train) on SVHN: 93.59%, +2.46%
# Accuracy (Test) on SVHN: 90.19%, +1.24%
# +1.24% with respect to maximum of 88.96%
# Best accuracy on source so far!
# --------------
# Source
# Source batch 0, epoch 10. Loss = 0.32074
# Source batch 50, epoch 10. Loss = 0.21609
# Source batch 100, epoch 10. Loss = 0.17049
# Source batch 150, epoch 10. Loss = 0.15761
# Source batch 200, epoch 10. Loss = 0.21319
# Source batch 250, epoch 10. Loss = 0.11912
# Source batch 300, epoch 10. Loss = 0.24223
# Source batch 350, epoch 10. Loss = 0.14465
# Source batch 400, epoch 10. Loss = 0.26169
# Source batch 450, epoch 10. Loss = 0.28917
# Source batch 500, epoch 10. Loss = 0.09990
# Source batch 550, epoch 10. Loss = 0.31988
# Source batch 600, epoch 10. Loss = 0.08148
# Source batch 650, epoch 10. Loss = 0.20800
# Source batch 700, epoch 10. Loss = 0.15939
# Source batch 750, epoch 10. Loss = 0.34951
# Source batch 800, epoch 10. Loss = 0.19239
# Source batch 850, epoch 10. Loss = 0.09272
# Source batch 900, epoch 10. Loss = 0.19919
# Source batch 950, epoch 10. Loss = 0.25279
# Source batch 1000, epoch 10. Loss = 0.18989
# Source batch 1050, epoch 10. Loss = 0.21441
# Source batch 1100, epoch 10. Loss = 0.23757
# --------------
# Experiment: 1/1
# Epoch 10/50 completed in 0.36426 minutes
# 5.912 minutes elapsed
# 14.64 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 11. Loss = 0.26364
# Source batch 50, epoch 11. Loss = 0.13800
# Source batch 100, epoch 11. Loss = 0.25352
# Source batch 150, epoch 11. Loss = 0.19111
# Source batch 200, epoch 11. Loss = 0.25473
# Source batch 250, epoch 11. Loss = 0.22266
# Source batch 300, epoch 11. Loss = 0.25109
# Source batch 350, epoch 11. Loss = 0.13686
# Source batch 400, epoch 11. Loss = 0.16736
# Source batch 450, epoch 11. Loss = 0.10851
# Source batch 500, epoch 11. Loss = 0.21548
# Source batch 550, epoch 11. Loss = 0.13216
# Source batch 600, epoch 11. Loss = 0.19879
# Source batch 650, epoch 11. Loss = 0.33423
# Source batch 700, epoch 11. Loss = 0.15329
# Source batch 750, epoch 11. Loss = 0.21311
# Source batch 800, epoch 11. Loss = 0.11277
# Source batch 850, epoch 11. Loss = 0.18708
# Source batch 900, epoch 11. Loss = 0.09206
# Source batch 950, epoch 11. Loss = 0.25132
# Source batch 1000, epoch 11. Loss = 0.43346
# Source batch 1050, epoch 11. Loss = 0.16405
# Source batch 1100, epoch 11. Loss = 0.42176
# --------------
# Experiment: 1/1
# Epoch 11/50 completed in 0.36538 minutes
# 6.277 minutes elapsed
# 14.27 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 12. Loss = 0.07500
# Source batch 50, epoch 12. Loss = 0.13341
# Source batch 100, epoch 12. Loss = 0.08128
# Source batch 150, epoch 12. Loss = 0.09280
# Source batch 200, epoch 12. Loss = 0.14571
# Source batch 250, epoch 12. Loss = 0.19113
# Source batch 300, epoch 12. Loss = 0.16837
# Source batch 350, epoch 12. Loss = 0.20553
# Source batch 400, epoch 12. Loss = 0.08732
# Source batch 450, epoch 12. Loss = 0.08024
# Source batch 500, epoch 12. Loss = 0.15750
# Source batch 550, epoch 12. Loss = 0.06589
# Source batch 600, epoch 12. Loss = 0.10012
# Source batch 650, epoch 12. Loss = 0.05685
# Source batch 700, epoch 12. Loss = 0.15877
# Source batch 750, epoch 12. Loss = 0.09759
# Source batch 800, epoch 12. Loss = 0.27590
# Source batch 850, epoch 12. Loss = 0.11754
# Source batch 900, epoch 12. Loss = 0.21027
# Source batch 950, epoch 12. Loss = 0.26891
# Source batch 1000, epoch 12. Loss = 0.14087
# Source batch 1050, epoch 12. Loss = 0.05353
# Source batch 1100, epoch 12. Loss = 0.20556
# --------------
# Experiment: 1/1
# Epoch 12/50 completed in 0.36218 minutes
# 6.639 minutes elapsed
# 13.90 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 13. Loss = 0.09080
# Source batch 50, epoch 13. Loss = 0.09116
# Source batch 100, epoch 13. Loss = 0.40947
# Source batch 150, epoch 13. Loss = 0.15567
# Source batch 200, epoch 13. Loss = 0.24668
# Source batch 250, epoch 13. Loss = 0.06235
# Source batch 300, epoch 13. Loss = 0.11872
# Source batch 350, epoch 13. Loss = 0.09220
# Source batch 400, epoch 13. Loss = 0.08090
# Source batch 450, epoch 13. Loss = 0.12877
# Source batch 500, epoch 13. Loss = 0.27784
# Source batch 550, epoch 13. Loss = 0.12818
# Source batch 600, epoch 13. Loss = 0.26066
# Source batch 650, epoch 13. Loss = 0.20923
# Source batch 700, epoch 13. Loss = 0.11410
# Source batch 750, epoch 13. Loss = 0.28742
# Source batch 800, epoch 13. Loss = 0.18198
# Source batch 850, epoch 13. Loss = 0.13151
# Source batch 900, epoch 13. Loss = 0.19650
# Source batch 950, epoch 13. Loss = 0.13393
# Source batch 1000, epoch 13. Loss = 0.13863
# Source batch 1050, epoch 13. Loss = 0.20865
# Source batch 1100, epoch 13. Loss = 0.19986
# --------------
# Experiment: 1/1
# Epoch 13/50 completed in 0.36342 minutes
# 7.003 minutes elapsed
# 13.52 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 14. Loss = 0.29615
# Source batch 50, epoch 14. Loss = 0.12984
# Source batch 100, epoch 14. Loss = 0.09917
# Source batch 150, epoch 14. Loss = 0.17438
# Source batch 200, epoch 14. Loss = 0.09094
# Source batch 250, epoch 14. Loss = 0.24096
# Source batch 300, epoch 14. Loss = 0.13778
# Source batch 350, epoch 14. Loss = 0.11814
# Source batch 400, epoch 14. Loss = 0.06807
# Source batch 450, epoch 14. Loss = 0.24626
# Source batch 500, epoch 14. Loss = 0.08675
# Source batch 550, epoch 14. Loss = 0.17104
# Source batch 600, epoch 14. Loss = 0.18569
# Source batch 650, epoch 14. Loss = 0.16080
# Source batch 700, epoch 14. Loss = 0.18703
# Source batch 750, epoch 14. Loss = 0.19714
# Source batch 800, epoch 14. Loss = 0.38671
# Source batch 850, epoch 14. Loss = 0.13545
# Source batch 900, epoch 14. Loss = 0.33234
# Source batch 950, epoch 14. Loss = 0.26040
# Source batch 1000, epoch 14. Loss = 0.47761
# Source batch 1050, epoch 14. Loss = 0.20552
# Source batch 1100, epoch 14. Loss = 0.14787
# --------------
# Experiment: 1/1
# Epoch 14/50 completed in 0.36438 minutes
# 7.367 minutes elapsed
# 13.15 minutes remaining
# --------------
# Validation run
# --------------
# Accuracy (Train) on SVHN: 94.17%, +0.59%
# Accuracy (Test) on SVHN: 89.96%, -0.23%
# -0.23% with respect to maximum of 90.19%
# --------------
# Source
# Source batch 0, epoch 15. Loss = 0.08702
# Source batch 50, epoch 15. Loss = 0.14151
# Source batch 100, epoch 15. Loss = 0.26662
# Source batch 150, epoch 15. Loss = 0.08823
# Source batch 200, epoch 15. Loss = 0.06183
# Source batch 250, epoch 15. Loss = 0.46251
# Source batch 300, epoch 15. Loss = 0.08788
# Source batch 350, epoch 15. Loss = 0.09413
# Source batch 400, epoch 15. Loss = 0.16120
# Source batch 450, epoch 15. Loss = 0.15303
# Source batch 500, epoch 15. Loss = 0.04591
# Source batch 550, epoch 15. Loss = 0.16126
# Source batch 600, epoch 15. Loss = 0.07935
# Source batch 650, epoch 15. Loss = 0.20229
# Source batch 700, epoch 15. Loss = 0.25770
# Source batch 750, epoch 15. Loss = 0.23139
# Source batch 800, epoch 15. Loss = 0.16432
# Source batch 850, epoch 15. Loss = 0.18154
# Source batch 900, epoch 15. Loss = 0.29299
# Source batch 950, epoch 15. Loss = 0.25636
# Source batch 1000, epoch 15. Loss = 0.07836
# Source batch 1050, epoch 15. Loss = 0.19856
# Source batch 1100, epoch 15. Loss = 0.32577
# --------------
# Experiment: 1/1
# Epoch 15/50 completed in 0.36042 minutes
# 8.101 minutes elapsed
# 12.78 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 16. Loss = 0.12151
# Source batch 50, epoch 16. Loss = 0.07385
# Source batch 100, epoch 16. Loss = 0.21957
# Source batch 150, epoch 16. Loss = 0.07562
# Source batch 200, epoch 16. Loss = 0.17126
# Source batch 250, epoch 16. Loss = 0.42757
# Source batch 300, epoch 16. Loss = 0.23474
# Source batch 350, epoch 16. Loss = 0.30906
# Source batch 400, epoch 16. Loss = 0.12391
# Source batch 450, epoch 16. Loss = 0.12841
# Source batch 500, epoch 16. Loss = 0.14841
# Source batch 550, epoch 16. Loss = 0.08193
# Source batch 600, epoch 16. Loss = 0.16347
# Source batch 650, epoch 16. Loss = 0.25732
# Source batch 700, epoch 16. Loss = 0.32047
# Source batch 750, epoch 16. Loss = 0.07712
# Source batch 800, epoch 16. Loss = 0.26773
# Source batch 850, epoch 16. Loss = 0.31372
# Source batch 900, epoch 16. Loss = 0.15082
# Source batch 950, epoch 16. Loss = 0.16642
# Source batch 1000, epoch 16. Loss = 0.16067
# Source batch 1050, epoch 16. Loss = 0.43295
# Source batch 1100, epoch 16. Loss = 0.10753
# --------------
# Experiment: 1/1
# Epoch 16/50 completed in 0.36346 minutes
# 8.465 minutes elapsed
# 12.41 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 17. Loss = 0.19659
# Source batch 50, epoch 17. Loss = 0.09076
# Source batch 100, epoch 17. Loss = 0.25099
# Source batch 150, epoch 17. Loss = 0.32568
# Source batch 200, epoch 17. Loss = 0.06119
# Source batch 250, epoch 17. Loss = 0.14568
# Source batch 300, epoch 17. Loss = 0.11566
# Source batch 350, epoch 17. Loss = 0.20056
# Source batch 400, epoch 17. Loss = 0.21914
# Source batch 450, epoch 17. Loss = 0.27907
# Source batch 500, epoch 17. Loss = 0.20845
# Source batch 550, epoch 17. Loss = 0.12412
# Source batch 600, epoch 17. Loss = 0.09946
# Source batch 650, epoch 17. Loss = 0.24755
# Source batch 700, epoch 17. Loss = 0.14206
# Source batch 750, epoch 17. Loss = 0.11570
# Source batch 800, epoch 17. Loss = 0.12719
# Source batch 850, epoch 17. Loss = 0.06598
# Source batch 900, epoch 17. Loss = 0.31024
# Source batch 950, epoch 17. Loss = 0.26603
# Source batch 1000, epoch 17. Loss = 0.24994
# Source batch 1050, epoch 17. Loss = 0.15154
# Source batch 1100, epoch 17. Loss = 0.17466
# --------------
# Experiment: 1/1
# Epoch 17/50 completed in 0.36587 minutes
# 8.830 minutes elapsed
# 12.05 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 18. Loss = 0.27386
# Source batch 50, epoch 18. Loss = 0.21107
# Source batch 100, epoch 18. Loss = 0.46268
# Source batch 150, epoch 18. Loss = 0.24620
# Source batch 200, epoch 18. Loss = 0.17898
# Source batch 250, epoch 18. Loss = 0.09654
# Source batch 300, epoch 18. Loss = 0.28362
# Source batch 350, epoch 18. Loss = 0.30090
# Source batch 400, epoch 18. Loss = 0.21836
# Source batch 450, epoch 18. Loss = 0.13979
# Source batch 500, epoch 18. Loss = 0.16507
# Source batch 550, epoch 18. Loss = 0.23232
# Source batch 600, epoch 18. Loss = 0.03996
# Source batch 650, epoch 18. Loss = 0.19470
# Source batch 700, epoch 18. Loss = 0.15958
# Source batch 750, epoch 18. Loss = 0.13740
# Source batch 800, epoch 18. Loss = 0.15923
# Source batch 850, epoch 18. Loss = 0.08192
# Source batch 900, epoch 18. Loss = 0.13546
# Source batch 950, epoch 18. Loss = 0.18688
# Source batch 1000, epoch 18. Loss = 0.10940
# Source batch 1050, epoch 18. Loss = 0.17972
# Source batch 1100, epoch 18. Loss = 0.08178
# --------------
# Experiment: 1/1
# Epoch 18/50 completed in 0.36171 minutes
# 9.192 minutes elapsed
# 11.68 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 19. Loss = 0.07315
# Source batch 50, epoch 19. Loss = 0.13721
# Source batch 100, epoch 19. Loss = 0.15327
# Source batch 150, epoch 19. Loss = 0.14244
# Source batch 200, epoch 19. Loss = 0.14517
# Source batch 250, epoch 19. Loss = 0.42248
# Source batch 300, epoch 19. Loss = 0.14135
# Source batch 350, epoch 19. Loss = 0.15810
# Source batch 400, epoch 19. Loss = 0.07474
# Source batch 450, epoch 19. Loss = 0.23450
# Source batch 500, epoch 19. Loss = 0.35713
# Source batch 550, epoch 19. Loss = 0.21939
# Source batch 600, epoch 19. Loss = 0.12715
# Source batch 650, epoch 19. Loss = 0.13436
# Source batch 700, epoch 19. Loss = 0.26637
# Source batch 750, epoch 19. Loss = 0.23118
# Source batch 800, epoch 19. Loss = 0.34481
# Source batch 850, epoch 19. Loss = 0.14117
# Source batch 900, epoch 19. Loss = 0.13961
# Source batch 950, epoch 19. Loss = 0.15649
# Source batch 1000, epoch 19. Loss = 0.09317
# Source batch 1050, epoch 19. Loss = 0.17910
# Source batch 1100, epoch 19. Loss = 0.27960
# --------------
# Experiment: 1/1
# Epoch 19/50 completed in 0.36387 minutes
# 9.556 minutes elapsed
# 11.31 minutes remaining
# --------------
# Validation run
# --------------
# Accuracy (Train) on SVHN: 94.72%, +0.54%
# Accuracy (Test) on SVHN: 91.03%, +1.07%
# +0.83% with respect to maximum of 90.19%
# Best accuracy on source so far!
# --------------
# Source
# Source batch 0, epoch 20. Loss = 0.09612
# Source batch 50, epoch 20. Loss = 0.17892
# Source batch 100, epoch 20. Loss = 0.21458
# Source batch 150, epoch 20. Loss = 0.14110
# Source batch 200, epoch 20. Loss = 0.35957
# Source batch 250, epoch 20. Loss = 0.06667
# Source batch 300, epoch 20. Loss = 0.16157
# Source batch 350, epoch 20. Loss = 0.25864
# Source batch 400, epoch 20. Loss = 0.15570
# Source batch 450, epoch 20. Loss = 0.18847
# Source batch 500, epoch 20. Loss = 0.24155
# Source batch 550, epoch 20. Loss = 0.21255
# Source batch 600, epoch 20. Loss = 0.20122
# Source batch 650, epoch 20. Loss = 0.14624
# Source batch 700, epoch 20. Loss = 0.17769
# Source batch 750, epoch 20. Loss = 0.20508
# Source batch 800, epoch 20. Loss = 0.24538
# Source batch 850, epoch 20. Loss = 0.14617
# Source batch 900, epoch 20. Loss = 0.35809
# Source batch 950, epoch 20. Loss = 0.14067
# Source batch 1000, epoch 20. Loss = 0.36316
# Source batch 1050, epoch 20. Loss = 0.12400
# Source batch 1100, epoch 20. Loss = 0.10076
# --------------
# Experiment: 1/1
# Epoch 20/50 completed in 0.36341 minutes
# 10.293 minutes elapsed
# 10.94 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 21. Loss = 0.19441
# Source batch 50, epoch 21. Loss = 0.08811
# Source batch 100, epoch 21. Loss = 0.08183
# Source batch 150, epoch 21. Loss = 0.10041
# Source batch 200, epoch 21. Loss = 0.28656
# Source batch 250, epoch 21. Loss = 0.38707
# Source batch 300, epoch 21. Loss = 0.06239
# Source batch 350, epoch 21. Loss = 0.14763
# Source batch 400, epoch 21. Loss = 0.22955
# Source batch 450, epoch 21. Loss = 0.20226
# Source batch 500, epoch 21. Loss = 0.19472
# Source batch 550, epoch 21. Loss = 0.24245
# Source batch 600, epoch 21. Loss = 0.05397
# Source batch 650, epoch 21. Loss = 0.26189
# Source batch 700, epoch 21. Loss = 0.22168
# Source batch 750, epoch 21. Loss = 0.12194
# Source batch 800, epoch 21. Loss = 0.18730
# Source batch 850, epoch 21. Loss = 0.03034
# Source batch 900, epoch 21. Loss = 0.29923
# Source batch 950, epoch 21. Loss = 0.21339
# Source batch 1000, epoch 21. Loss = 0.12288
# Source batch 1050, epoch 21. Loss = 0.18094
# Source batch 1100, epoch 21. Loss = 0.18379
# --------------
# Experiment: 1/1
# Epoch 21/50 completed in 0.36284 minutes
# 10.656 minutes elapsed
# 10.57 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 22. Loss = 0.22316
# Source batch 50, epoch 22. Loss = 0.25523
# Source batch 100, epoch 22. Loss = 0.19291
# Source batch 150, epoch 22. Loss = 0.40471
# Source batch 200, epoch 22. Loss = 0.24272
# Source batch 250, epoch 22. Loss = 0.10919
# Source batch 300, epoch 22. Loss = 0.14363
# Source batch 350, epoch 22. Loss = 0.35278
# Source batch 400, epoch 22. Loss = 0.19100
# Source batch 450, epoch 22. Loss = 0.10705
# Source batch 500, epoch 22. Loss = 0.07052
# Source batch 550, epoch 22. Loss = 0.38731
# Source batch 600, epoch 22. Loss = 0.34835
# Source batch 650, epoch 22. Loss = 0.32385
# Source batch 700, epoch 22. Loss = 0.06041
# Source batch 750, epoch 22. Loss = 0.28116
# Source batch 800, epoch 22. Loss = 0.22335
# Source batch 850, epoch 22. Loss = 0.10202
# Source batch 900, epoch 22. Loss = 0.27013
# Source batch 950, epoch 22. Loss = 0.20336
# Source batch 1000, epoch 22. Loss = 0.19696
# Source batch 1050, epoch 22. Loss = 0.23826
# Source batch 1100, epoch 22. Loss = 0.20865
# --------------
# Experiment: 1/1
# Epoch 22/50 completed in 0.36463 minutes
# 11.021 minutes elapsed
# 10.21 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 23. Loss = 0.11216
# Source batch 50, epoch 23. Loss = 0.13364
# Source batch 100, epoch 23. Loss = 0.40041
# Source batch 150, epoch 23. Loss = 0.28229
# Source batch 200, epoch 23. Loss = 0.08916
# Source batch 250, epoch 23. Loss = 0.18237
# Source batch 300, epoch 23. Loss = 0.09828
# Source batch 350, epoch 23. Loss = 0.22175
# Source batch 400, epoch 23. Loss = 0.23645
# Source batch 450, epoch 23. Loss = 0.24320
# Source batch 500, epoch 23. Loss = 0.13627
# Source batch 550, epoch 23. Loss = 0.33539
# Source batch 600, epoch 23. Loss = 0.27312
# Source batch 650, epoch 23. Loss = 0.18294
# Source batch 700, epoch 23. Loss = 0.05490
# Source batch 750, epoch 23. Loss = 0.12931
# Source batch 800, epoch 23. Loss = 0.14021
# Source batch 850, epoch 23. Loss = 0.19598
# Source batch 900, epoch 23. Loss = 0.29956
# Source batch 950, epoch 23. Loss = 0.15190
# Source batch 1000, epoch 23. Loss = 0.27171
# Source batch 1050, epoch 23. Loss = 0.24925
# Source batch 1100, epoch 23. Loss = 0.13515
# --------------
# Experiment: 1/1
# Epoch 23/50 completed in 0.36555 minutes
# 11.386 minutes elapsed
# 9.85 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 24. Loss = 0.16632
# Source batch 50, epoch 24. Loss = 0.13188
# Source batch 100, epoch 24. Loss = 0.13145
# Source batch 150, epoch 24. Loss = 0.25733
# Source batch 200, epoch 24. Loss = 0.21799
# Source batch 250, epoch 24. Loss = 0.23471
# Source batch 300, epoch 24. Loss = 0.20776
# Source batch 350, epoch 24. Loss = 0.21058
# Source batch 400, epoch 24. Loss = 0.13901
# Source batch 450, epoch 24. Loss = 0.09123
# Source batch 500, epoch 24. Loss = 0.14932
# Source batch 550, epoch 24. Loss = 0.13062
# Source batch 600, epoch 24. Loss = 0.09286
# Source batch 650, epoch 24. Loss = 0.20246
# Source batch 700, epoch 24. Loss = 0.06469
# Source batch 750, epoch 24. Loss = 0.22562
# Source batch 800, epoch 24. Loss = 0.14111
# Source batch 850, epoch 24. Loss = 0.17686
# Source batch 900, epoch 24. Loss = 0.42280
# Source batch 950, epoch 24. Loss = 0.09187
# Source batch 1000, epoch 24. Loss = 0.13174
# Source batch 1050, epoch 24. Loss = 0.32852
# Source batch 1100, epoch 24. Loss = 0.30128
# --------------
# Experiment: 1/1
# Epoch 24/50 completed in 0.36565 minutes
# 11.752 minutes elapsed
# 9.48 minutes remaining
# --------------
# Validation run
# --------------
# Accuracy (Train) on SVHN: 94.57%, -0.14%
# Accuracy (Test) on SVHN: 91.10%, +0.08%
# +0.08% with respect to maximum of 91.03%
# Best accuracy on source so far!
# --------------
# Source
# Source batch 0, epoch 25. Loss = 0.14646
# Source batch 50, epoch 25. Loss = 0.08355
# Source batch 100, epoch 25. Loss = 0.19114
# Source batch 150, epoch 25. Loss = 0.17322
# Source batch 200, epoch 25. Loss = 0.12663
# Source batch 250, epoch 25. Loss = 0.22268
# Source batch 300, epoch 25. Loss = 0.33332
# Source batch 350, epoch 25. Loss = 0.19831
# Source batch 400, epoch 25. Loss = 0.27188
# Source batch 450, epoch 25. Loss = 0.10847
# Source batch 500, epoch 25. Loss = 0.28068
# Source batch 550, epoch 25. Loss = 0.16565
# Source batch 600, epoch 25. Loss = 0.16765
# Source batch 650, epoch 25. Loss = 0.12396
# Source batch 700, epoch 25. Loss = 0.03835
# Source batch 750, epoch 25. Loss = 0.72856
# Source batch 800, epoch 25. Loss = 0.33404
# Source batch 850, epoch 25. Loss = 0.11760
# Source batch 900, epoch 25. Loss = 0.13136
# Source batch 950, epoch 25. Loss = 0.21605
# Source batch 1000, epoch 25. Loss = 0.14003
# Source batch 1050, epoch 25. Loss = 0.21431
# Source batch 1100, epoch 25. Loss = 0.15641
# --------------
# Experiment: 1/1
# Epoch 25/50 completed in 0.36752 minutes
# 12.492 minutes elapsed
# 9.12 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 26. Loss = 0.18018
# Source batch 50, epoch 26. Loss = 0.29834
# Source batch 100, epoch 26. Loss = 0.24789
# Source batch 150, epoch 26. Loss = 0.09841
# Source batch 200, epoch 26. Loss = 0.20195
# Source batch 250, epoch 26. Loss = 0.11776
# Source batch 300, epoch 26. Loss = 0.18582
# Source batch 350, epoch 26. Loss = 0.14699
# Source batch 400, epoch 26. Loss = 0.18609
# Source batch 450, epoch 26. Loss = 0.26143
# Source batch 500, epoch 26. Loss = 0.13672
# Source batch 550, epoch 26. Loss = 0.26626
# Source batch 600, epoch 26. Loss = 0.15310
# Source batch 650, epoch 26. Loss = 0.11953
# Source batch 700, epoch 26. Loss = 0.18889
# Source batch 750, epoch 26. Loss = 0.20705
# Source batch 800, epoch 26. Loss = 0.34744
# Source batch 850, epoch 26. Loss = 0.12482
# Source batch 900, epoch 26. Loss = 0.30834
# Source batch 950, epoch 26. Loss = 0.36210
# Source batch 1000, epoch 26. Loss = 0.19589
# Source batch 1050, epoch 26. Loss = 0.19617
# Source batch 1100, epoch 26. Loss = 0.32193
# --------------
# Experiment: 1/1
# Epoch 26/50 completed in 0.36710 minutes
# 12.859 minutes elapsed
# 8.76 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 27. Loss = 0.13021
# Source batch 50, epoch 27. Loss = 0.31588
# Source batch 100, epoch 27. Loss = 0.08164
# Source batch 150, epoch 27. Loss = 0.37890
# Source batch 200, epoch 27. Loss = 0.31922
# Source batch 250, epoch 27. Loss = 0.12120
# Source batch 300, epoch 27. Loss = 0.17427
# Source batch 350, epoch 27. Loss = 0.06701
# Source batch 400, epoch 27. Loss = 0.16511
# Source batch 450, epoch 27. Loss = 0.23834
# Source batch 500, epoch 27. Loss = 0.15502
# Source batch 550, epoch 27. Loss = 0.12385
# Source batch 600, epoch 27. Loss = 0.18364
# Source batch 650, epoch 27. Loss = 0.03789
# Source batch 700, epoch 27. Loss = 0.21352
# Source batch 750, epoch 27. Loss = 0.16405
# Source batch 800, epoch 27. Loss = 0.36163
# Source batch 850, epoch 27. Loss = 0.07897
# Source batch 900, epoch 27. Loss = 0.16586
# Source batch 950, epoch 27. Loss = 0.12006
# Source batch 1000, epoch 27. Loss = 0.18734
# Source batch 1050, epoch 27. Loss = 0.21710
# Source batch 1100, epoch 27. Loss = 0.40833
# --------------
# Experiment: 1/1
# Epoch 27/50 completed in 0.36562 minutes
# 13.225 minutes elapsed
# 8.39 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 28. Loss = 0.10013
# Source batch 50, epoch 28. Loss = 0.21319
# Source batch 100, epoch 28. Loss = 0.53025
# Source batch 150, epoch 28. Loss = 0.12736
# Source batch 200, epoch 28. Loss = 0.13733
# Source batch 250, epoch 28. Loss = 0.24091
# Source batch 300, epoch 28. Loss = 0.19125
# Source batch 350, epoch 28. Loss = 0.07393
# Source batch 400, epoch 28. Loss = 0.08297
# Source batch 450, epoch 28. Loss = 0.20785
# Source batch 500, epoch 28. Loss = 0.15037
# Source batch 550, epoch 28. Loss = 0.07651
# Source batch 600, epoch 28. Loss = 0.15399
# Source batch 650, epoch 28. Loss = 0.13638
# Source batch 700, epoch 28. Loss = 0.04998
# Source batch 750, epoch 28. Loss = 0.27414
# Source batch 800, epoch 28. Loss = 0.33751
# Source batch 850, epoch 28. Loss = 0.16478
# Source batch 900, epoch 28. Loss = 0.21378
# Source batch 950, epoch 28. Loss = 0.13832
# Source batch 1000, epoch 28. Loss = 0.41085
# Source batch 1050, epoch 28. Loss = 0.16555
# Source batch 1100, epoch 28. Loss = 0.14215
# --------------
# Experiment: 1/1
# Epoch 28/50 completed in 0.36348 minutes
# 13.589 minutes elapsed
# 8.03 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 29. Loss = 0.17854
# Source batch 50, epoch 29. Loss = 0.25715
# Source batch 100, epoch 29. Loss = 0.03314
# Source batch 150, epoch 29. Loss = 0.24804
# Source batch 200, epoch 29. Loss = 0.26080
# Source batch 250, epoch 29. Loss = 0.07796
# Source batch 300, epoch 29. Loss = 0.38321
# Source batch 350, epoch 29. Loss = 0.09328
# Source batch 400, epoch 29. Loss = 0.25994
# Source batch 450, epoch 29. Loss = 0.36081
# Source batch 500, epoch 29. Loss = 0.30803
# Source batch 550, epoch 29. Loss = 0.34983
# Source batch 600, epoch 29. Loss = 0.24719
# Source batch 650, epoch 29. Loss = 0.14693
# Source batch 700, epoch 29. Loss = 0.10380
# Source batch 750, epoch 29. Loss = 0.11277
# Source batch 800, epoch 29. Loss = 0.22952
# Source batch 850, epoch 29. Loss = 0.13509
# Source batch 900, epoch 29. Loss = 0.24145
# Source batch 950, epoch 29. Loss = 0.03633
# Source batch 1000, epoch 29. Loss = 0.11227
# Source batch 1050, epoch 29. Loss = 0.25539
# Source batch 1100, epoch 29. Loss = 0.28635
# --------------
# Experiment: 1/1
# Epoch 29/50 completed in 0.36545 minutes
# 13.954 minutes elapsed
# 7.66 minutes remaining
# --------------
# Validation run
# --------------
# Accuracy (Train) on SVHN: 94.87%, +0.30%
# Accuracy (Test) on SVHN: 90.31%, -0.80%
# -0.80% with respect to maximum of 91.10%
# --------------
# Source
# Source batch 0, epoch 30. Loss = 0.15161
# Source batch 50, epoch 30. Loss = 0.13619
# Source batch 100, epoch 30. Loss = 0.10620
# Source batch 150, epoch 30. Loss = 0.20786
# Source batch 200, epoch 30. Loss = 0.13332
# Source batch 250, epoch 30. Loss = 0.12297
# Source batch 300, epoch 30. Loss = 0.29058
# Source batch 350, epoch 30. Loss = 0.14683
# Source batch 400, epoch 30. Loss = 0.04812
# Source batch 450, epoch 30. Loss = 0.23435
# Source batch 500, epoch 30. Loss = 0.10219
# Source batch 550, epoch 30. Loss = 0.05135
# Source batch 600, epoch 30. Loss = 0.14080
# Source batch 650, epoch 30. Loss = 0.14032
# Source batch 700, epoch 30. Loss = 0.07895
# Source batch 750, epoch 30. Loss = 0.13143
# Source batch 800, epoch 30. Loss = 0.11664
# Source batch 850, epoch 30. Loss = 0.14001
# Source batch 900, epoch 30. Loss = 0.18112
# Source batch 950, epoch 30. Loss = 0.16133
# Source batch 1000, epoch 30. Loss = 0.10151
# Source batch 1050, epoch 30. Loss = 0.05971
# Source batch 1100, epoch 30. Loss = 0.14453
# --------------
# Experiment: 1/1
# Epoch 30/50 completed in 0.37621 minutes
# 14.704 minutes elapsed
# 7.31 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 31. Loss = 0.17721
# Source batch 50, epoch 31. Loss = 0.18630
# Source batch 100, epoch 31. Loss = 0.10718
# Source batch 150, epoch 31. Loss = 0.06993
# Source batch 200, epoch 31. Loss = 0.09633
# Source batch 250, epoch 31. Loss = 0.14119
# Source batch 300, epoch 31. Loss = 0.00612
# Source batch 350, epoch 31. Loss = 0.25745
# Source batch 400, epoch 31. Loss = 0.09721
# Source batch 450, epoch 31. Loss = 0.22627
# Source batch 500, epoch 31. Loss = 0.15065
# Source batch 550, epoch 31. Loss = 0.10903
# Source batch 600, epoch 31. Loss = 0.12861
# Source batch 650, epoch 31. Loss = 0.09763
# Source batch 700, epoch 31. Loss = 0.14632
# Source batch 750, epoch 31. Loss = 0.13611
# Source batch 800, epoch 31. Loss = 0.08255
# Source batch 850, epoch 31. Loss = 0.10189
# Source batch 900, epoch 31. Loss = 0.37292
# Source batch 950, epoch 31. Loss = 0.23162
# Source batch 1000, epoch 31. Loss = 0.27995
# Source batch 1050, epoch 31. Loss = 0.16482
# Source batch 1100, epoch 31. Loss = 0.38803
# --------------
# Experiment: 1/1
# Epoch 31/50 completed in 0.37495 minutes
# 15.079 minutes elapsed
# 6.95 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 32. Loss = 0.06179
# Source batch 50, epoch 32. Loss = 0.18764
# Source batch 100, epoch 32. Loss = 0.20752
# Source batch 150, epoch 32. Loss = 0.16760
# Source batch 200, epoch 32. Loss = 0.13163
# Source batch 250, epoch 32. Loss = 0.11191
# Source batch 300, epoch 32. Loss = 0.13986
# Source batch 350, epoch 32. Loss = 0.12628
# Source batch 400, epoch 32. Loss = 0.31167
# Source batch 450, epoch 32. Loss = 0.15831
# Source batch 500, epoch 32. Loss = 0.19315
# Source batch 550, epoch 32. Loss = 0.07295
# Source batch 600, epoch 32. Loss = 0.18793
# Source batch 650, epoch 32. Loss = 0.66529
# Source batch 700, epoch 32. Loss = 0.42015
# Source batch 750, epoch 32. Loss = 0.04918
# Source batch 800, epoch 32. Loss = 0.19793
# Source batch 850, epoch 32. Loss = 0.18627
# Source batch 900, epoch 32. Loss = 0.17034
# Source batch 950, epoch 32. Loss = 0.41602
# Source batch 1000, epoch 32. Loss = 0.16280
# Source batch 1050, epoch 32. Loss = 0.08704
# Source batch 1100, epoch 32. Loss = 0.12516
# --------------
# Experiment: 1/1
# Epoch 32/50 completed in 0.37766 minutes
# 15.456 minutes elapsed
# 6.59 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 33. Loss = 0.16871
# Source batch 50, epoch 33. Loss = 0.20750
# Source batch 100, epoch 33. Loss = 0.11979
# Source batch 150, epoch 33. Loss = 0.23288
# Source batch 200, epoch 33. Loss = 0.17167
# Source batch 250, epoch 33. Loss = 0.20506
# Source batch 300, epoch 33. Loss = 0.10228
# Source batch 350, epoch 33. Loss = 0.04370
# Source batch 400, epoch 33. Loss = 0.25492
# Source batch 450, epoch 33. Loss = 0.15364
# Source batch 500, epoch 33. Loss = 0.24116
# Source batch 550, epoch 33. Loss = 0.19195
# Source batch 600, epoch 33. Loss = 0.19374
# Source batch 650, epoch 33. Loss = 0.21002
# Source batch 700, epoch 33. Loss = 0.29457
# Source batch 750, epoch 33. Loss = 0.11725
# Source batch 800, epoch 33. Loss = 0.10058
# Source batch 850, epoch 33. Loss = 0.27960
# Source batch 900, epoch 33. Loss = 0.28769
# Source batch 950, epoch 33. Loss = 0.11624
# Source batch 1000, epoch 33. Loss = 0.32091
# Source batch 1050, epoch 33. Loss = 0.20342
# Source batch 1100, epoch 33. Loss = 0.18564
# --------------
# Experiment: 1/1
# Epoch 33/50 completed in 0.37043 minutes
# 15.827 minutes elapsed
# 6.22 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 34. Loss = 0.18515
# Source batch 50, epoch 34. Loss = 0.27065
# Source batch 100, epoch 34. Loss = 0.15446
# Source batch 150, epoch 34. Loss = 0.17266
# Source batch 200, epoch 34. Loss = 0.07474
# Source batch 250, epoch 34. Loss = 0.23737
# Source batch 300, epoch 34. Loss = 0.36795
# Source batch 350, epoch 34. Loss = 0.20117
# Source batch 400, epoch 34. Loss = 0.26298
# Source batch 450, epoch 34. Loss = 0.31401
# Source batch 500, epoch 34. Loss = 0.15946
# Source batch 550, epoch 34. Loss = 0.20430
# Source batch 600, epoch 34. Loss = 0.22498
# Source batch 650, epoch 34. Loss = 0.14808
# Source batch 700, epoch 34. Loss = 0.20565
# Source batch 750, epoch 34. Loss = 0.10040
# Source batch 800, epoch 34. Loss = 0.29925
# Source batch 850, epoch 34. Loss = 0.13500
# Source batch 900, epoch 34. Loss = 0.18752
# Source batch 950, epoch 34. Loss = 0.18582
# Source batch 1000, epoch 34. Loss = 0.22905
# Source batch 1050, epoch 34. Loss = 0.14139
# Source batch 1100, epoch 34. Loss = 0.21348
# --------------
# Experiment: 1/1
# Epoch 34/50 completed in 0.37626 minutes
# 16.203 minutes elapsed
# 5.86 minutes remaining
# --------------
# Validation run
# --------------
# Accuracy (Train) on SVHN: 94.17%, -0.70%
# Accuracy (Test) on SVHN: 90.34%, +0.03%
# -0.76% with respect to maximum of 91.10%
# --------------
# Source
# Source batch 0, epoch 35. Loss = 0.12259
# Source batch 50, epoch 35. Loss = 0.06195
# Source batch 100, epoch 35. Loss = 0.34000
# Source batch 150, epoch 35. Loss = 0.27450
# Source batch 200, epoch 35. Loss = 0.20083
# Source batch 250, epoch 35. Loss = 0.17988
# Source batch 300, epoch 35. Loss = 0.38357
# Source batch 350, epoch 35. Loss = 0.05607
# Source batch 400, epoch 35. Loss = 0.26285
# Source batch 450, epoch 35. Loss = 0.11140
# Source batch 500, epoch 35. Loss = 0.24984
# Source batch 550, epoch 35. Loss = 0.12756
# Source batch 600, epoch 35. Loss = 0.07882
# Source batch 650, epoch 35. Loss = 0.19344
# Source batch 700, epoch 35. Loss = 0.26328
# Source batch 750, epoch 35. Loss = 0.11708
# Source batch 800, epoch 35. Loss = 0.24962
# Source batch 850, epoch 35. Loss = 0.24519
# Source batch 900, epoch 35. Loss = 0.27942
# Source batch 950, epoch 35. Loss = 0.19600
# Source batch 1000, epoch 35. Loss = 0.27601
# Source batch 1050, epoch 35. Loss = 0.04334
# Source batch 1100, epoch 35. Loss = 0.22181
# --------------
# Experiment: 1/1
# Epoch 35/50 completed in 0.37458 minutes
# 16.958 minutes elapsed
# 5.50 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 36. Loss = 0.17955
# Source batch 50, epoch 36. Loss = 0.11920
# Source batch 100, epoch 36. Loss = 0.12047
# Source batch 150, epoch 36. Loss = 0.22050
# Source batch 200, epoch 36. Loss = 0.13725
# Source batch 250, epoch 36. Loss = 0.32539
# Source batch 300, epoch 36. Loss = 0.07057
# Source batch 350, epoch 36. Loss = 0.10343
# Source batch 400, epoch 36. Loss = 0.37391
# Source batch 450, epoch 36. Loss = 0.10978
# Source batch 500, epoch 36. Loss = 0.25100
# Source batch 550, epoch 36. Loss = 0.26077
# Source batch 600, epoch 36. Loss = 0.21176
# Source batch 650, epoch 36. Loss = 0.10176
# Source batch 700, epoch 36. Loss = 0.42347
# Source batch 750, epoch 36. Loss = 0.20253
# Source batch 800, epoch 36. Loss = 0.26927
# Source batch 850, epoch 36. Loss = 0.17541
# Source batch 900, epoch 36. Loss = 0.15285
# Source batch 950, epoch 36. Loss = 0.17100
# Source batch 1000, epoch 36. Loss = 0.21580
# Source batch 1050, epoch 36. Loss = 0.11740
# Source batch 1100, epoch 36. Loss = 0.07530
# --------------
# Experiment: 1/1
# Epoch 36/50 completed in 0.37639 minutes
# 17.334 minutes elapsed
# 5.14 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 37. Loss = 0.19406
# Source batch 50, epoch 37. Loss = 0.11414
# Source batch 100, epoch 37. Loss = 0.14448
# Source batch 150, epoch 37. Loss = 0.18458
# Source batch 200, epoch 37. Loss = 0.15597
# Source batch 250, epoch 37. Loss = 0.21984
# Source batch 300, epoch 37. Loss = 0.08347
# Source batch 350, epoch 37. Loss = 0.09008
# Source batch 400, epoch 37. Loss = 0.10634
# Source batch 450, epoch 37. Loss = 0.21370
# Source batch 500, epoch 37. Loss = 0.22855
# Source batch 550, epoch 37. Loss = 0.15312
# Source batch 600, epoch 37. Loss = 0.18407
# Source batch 650, epoch 37. Loss = 0.12646
# Source batch 700, epoch 37. Loss = 0.21008
# Source batch 750, epoch 37. Loss = 0.13363
# Source batch 800, epoch 37. Loss = 0.08418
# Source batch 850, epoch 37. Loss = 0.21488
# Source batch 900, epoch 37. Loss = 0.13290
# Source batch 950, epoch 37. Loss = 0.27420
# Source batch 1000, epoch 37. Loss = 0.22037
# Source batch 1050, epoch 37. Loss = 0.28374
# Source batch 1100, epoch 37. Loss = 0.11840
# --------------
# Experiment: 1/1
# Epoch 37/50 completed in 0.37021 minutes
# 17.704 minutes elapsed
# 4.77 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 38. Loss = 0.13075
# Source batch 50, epoch 38. Loss = 0.21050
# Source batch 100, epoch 38. Loss = 0.14222
# Source batch 150, epoch 38. Loss = 0.25991
# Source batch 200, epoch 38. Loss = 0.20094
# Source batch 250, epoch 38. Loss = 0.16433
# Source batch 300, epoch 38. Loss = 0.21101
# Source batch 350, epoch 38. Loss = 0.03326
# Source batch 400, epoch 38. Loss = 0.18766
# Source batch 450, epoch 38. Loss = 0.14265
# Source batch 500, epoch 38. Loss = 0.12597
# Source batch 550, epoch 38. Loss = 0.08573
# Source batch 600, epoch 38. Loss = 0.21137
# Source batch 650, epoch 38. Loss = 0.21913
# Source batch 700, epoch 38. Loss = 0.13335
# Source batch 750, epoch 38. Loss = 0.17061
# Source batch 800, epoch 38. Loss = 0.17086
# Source batch 850, epoch 38. Loss = 0.07747
# Source batch 900, epoch 38. Loss = 0.15193
# Source batch 950, epoch 38. Loss = 0.18164
# Source batch 1000, epoch 38. Loss = 0.13351
# Source batch 1050, epoch 38. Loss = 0.04022
# Source batch 1100, epoch 38. Loss = 0.17911
# --------------
# Experiment: 1/1
# Epoch 38/50 completed in 0.37714 minutes
# 18.081 minutes elapsed
# 4.41 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 39. Loss = 0.13556
# Source batch 50, epoch 39. Loss = 0.17220
# Source batch 100, epoch 39. Loss = 0.29270
# Source batch 150, epoch 39. Loss = 0.17995
# Source batch 200, epoch 39. Loss = 0.08432
# Source batch 250, epoch 39. Loss = 0.16687
# Source batch 300, epoch 39. Loss = 0.07776
# Source batch 350, epoch 39. Loss = 0.11718
# Source batch 400, epoch 39. Loss = 0.25666
# Source batch 450, epoch 39. Loss = 0.20514
# Source batch 500, epoch 39. Loss = 0.16216
# Source batch 550, epoch 39. Loss = 0.19656
# Source batch 600, epoch 39. Loss = 0.10698
# Source batch 650, epoch 39. Loss = 0.31647
# Source batch 700, epoch 39. Loss = 0.26997
# Source batch 750, epoch 39. Loss = 0.21195
# Source batch 800, epoch 39. Loss = 0.19587
# Source batch 850, epoch 39. Loss = 0.19712
# Source batch 900, epoch 39. Loss = 0.14819
# Source batch 950, epoch 39. Loss = 0.23605
# Source batch 1000, epoch 39. Loss = 0.33167
# Source batch 1050, epoch 39. Loss = 0.21783
# Source batch 1100, epoch 39. Loss = 0.22543
# --------------
# Experiment: 1/1
# Epoch 39/50 completed in 0.37629 minutes
# 18.458 minutes elapsed
# 4.04 minutes remaining
# --------------
# Validation run
# --------------
# Accuracy (Train) on SVHN: 94.03%, -0.14%
# Accuracy (Test) on SVHN: 90.28%, -0.06%
# -0.82% with respect to maximum of 91.10%
# --------------
# Source
# Source batch 0, epoch 40. Loss = 0.12818
# Source batch 50, epoch 40. Loss = 0.24666
# Source batch 100, epoch 40. Loss = 0.13050
# Source batch 150, epoch 40. Loss = 0.12628
# Source batch 200, epoch 40. Loss = 0.04574
# Source batch 250, epoch 40. Loss = 0.11623
# Source batch 300, epoch 40. Loss = 0.28117
# Source batch 350, epoch 40. Loss = 0.23501
# Source batch 400, epoch 40. Loss = 0.12054
# Source batch 450, epoch 40. Loss = 0.11115
# Source batch 500, epoch 40. Loss = 0.14294
# Source batch 550, epoch 40. Loss = 0.30875
# Source batch 600, epoch 40. Loss = 0.15648
# Source batch 650, epoch 40. Loss = 0.24896
# Source batch 700, epoch 40. Loss = 0.18235
# Source batch 750, epoch 40. Loss = 0.13246
# Source batch 800, epoch 40. Loss = 0.08020
# Source batch 850, epoch 40. Loss = 0.07560
# Source batch 900, epoch 40. Loss = 0.10677
# Source batch 950, epoch 40. Loss = 0.26642
# Source batch 1000, epoch 40. Loss = 0.09678
# Source batch 1050, epoch 40. Loss = 0.23754
# Source batch 1100, epoch 40. Loss = 0.09720
# --------------
# Experiment: 1/1
# Epoch 40/50 completed in 0.39331 minutes
# 19.248 minutes elapsed
# 3.68 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 41. Loss = 0.17618
# Source batch 50, epoch 41. Loss = 0.08114
# Source batch 100, epoch 41. Loss = 0.10000
# Source batch 150, epoch 41. Loss = 0.22661
# Source batch 200, epoch 41. Loss = 0.31441
# Source batch 250, epoch 41. Loss = 0.29903
# Source batch 300, epoch 41. Loss = 0.14042
# Source batch 350, epoch 41. Loss = 0.14754
# Source batch 400, epoch 41. Loss = 0.10231
# Source batch 450, epoch 41. Loss = 0.10054
# Source batch 500, epoch 41. Loss = 0.10508
# Source batch 550, epoch 41. Loss = 0.15787
# Source batch 600, epoch 41. Loss = 0.12998
# Source batch 650, epoch 41. Loss = 0.13699
# Source batch 700, epoch 41. Loss = 0.40658
# Source batch 750, epoch 41. Loss = 0.11545
# Source batch 800, epoch 41. Loss = 0.24395
# Source batch 850, epoch 41. Loss = 0.09592
# Source batch 900, epoch 41. Loss = 0.10827
# Source batch 950, epoch 41. Loss = 0.12846
# Source batch 1000, epoch 41. Loss = 0.69870
# Source batch 1050, epoch 41. Loss = 0.20337
# Source batch 1100, epoch 41. Loss = 0.12090
# --------------
# Experiment: 1/1
# Epoch 41/50 completed in 0.39202 minutes
# 19.640 minutes elapsed
# 3.32 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 42. Loss = 0.15183
# Source batch 50, epoch 42. Loss = 0.14744
# Source batch 100, epoch 42. Loss = 0.16815
# Source batch 150, epoch 42. Loss = 0.05327
# Source batch 200, epoch 42. Loss = 0.17021
# Source batch 250, epoch 42. Loss = 0.14065
# Source batch 300, epoch 42. Loss = 0.16491
# Source batch 350, epoch 42. Loss = 0.12698
# Source batch 400, epoch 42. Loss = 0.01618
# Source batch 450, epoch 42. Loss = 0.25256
# Source batch 500, epoch 42. Loss = 0.03434
# Source batch 550, epoch 42. Loss = 0.23931
# Source batch 600, epoch 42. Loss = 0.16662
# Source batch 650, epoch 42. Loss = 0.21182
# Source batch 700, epoch 42. Loss = 0.15124
# Source batch 750, epoch 42. Loss = 0.12584
# Source batch 800, epoch 42. Loss = 0.13260
# Source batch 850, epoch 42. Loss = 0.21935
# Source batch 900, epoch 42. Loss = 0.30993
# Source batch 950, epoch 42. Loss = 0.27206
# Source batch 1000, epoch 42. Loss = 0.32691
# Source batch 1050, epoch 42. Loss = 0.14562
# Source batch 1100, epoch 42. Loss = 0.29577
# --------------
# Experiment: 1/1
# Epoch 42/50 completed in 0.39069 minutes
# 20.031 minutes elapsed
# 2.95 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 43. Loss = 0.15476
# Source batch 50, epoch 43. Loss = 0.18365
# Source batch 100, epoch 43. Loss = 0.06946
# Source batch 150, epoch 43. Loss = 0.12519
# Source batch 200, epoch 43. Loss = 0.60482
# Source batch 250, epoch 43. Loss = 0.18098
# Source batch 300, epoch 43. Loss = 0.39057
# Source batch 350, epoch 43. Loss = 0.03943
# Source batch 400, epoch 43. Loss = 0.23160
# Source batch 450, epoch 43. Loss = 0.10161
# Source batch 500, epoch 43. Loss = 0.29380
# Source batch 550, epoch 43. Loss = 0.15576
# Source batch 600, epoch 43. Loss = 0.18027
# Source batch 650, epoch 43. Loss = 0.23258
# Source batch 700, epoch 43. Loss = 0.14683
# Source batch 750, epoch 43. Loss = 0.13006
# Source batch 800, epoch 43. Loss = 0.12775
# Source batch 850, epoch 43. Loss = 0.17838
# Source batch 900, epoch 43. Loss = 0.23032
# Source batch 950, epoch 43. Loss = 0.13416
# Source batch 1000, epoch 43. Loss = 0.21272
# Source batch 1050, epoch 43. Loss = 0.38114
# Source batch 1100, epoch 43. Loss = 0.13370
# --------------
# Experiment: 1/1
# Epoch 43/50 completed in 0.36807 minutes
# 20.399 minutes elapsed
# 2.58 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 44. Loss = 0.13756
# Source batch 50, epoch 44. Loss = 0.03907
# Source batch 100, epoch 44. Loss = 0.17438
# Source batch 150, epoch 44. Loss = 0.17760
# Source batch 200, epoch 44. Loss = 0.19715
# Source batch 250, epoch 44. Loss = 0.15086
# Source batch 300, epoch 44. Loss = 0.17832
# Source batch 350, epoch 44. Loss = 0.21773
# Source batch 400, epoch 44. Loss = 0.09123
# Source batch 450, epoch 44. Loss = 0.25861
# Source batch 500, epoch 44. Loss = 0.11069
# Source batch 550, epoch 44. Loss = 0.11376
# Source batch 600, epoch 44. Loss = 0.14974
# Source batch 650, epoch 44. Loss = 0.12795
# Source batch 700, epoch 44. Loss = 0.08984
# Source batch 750, epoch 44. Loss = 0.05659
# Source batch 800, epoch 44. Loss = 0.25151
# Source batch 850, epoch 44. Loss = 0.25997
# Source batch 900, epoch 44. Loss = 0.26544
# Source batch 950, epoch 44. Loss = 0.04775
# Source batch 1000, epoch 44. Loss = 0.23711
# Source batch 1050, epoch 44. Loss = 0.27508
# Source batch 1100, epoch 44. Loss = 0.35762
# --------------
# Experiment: 1/1
# Epoch 44/50 completed in 0.36619 minutes
# 20.765 minutes elapsed
# 2.21 minutes remaining
# --------------
# Validation run
# --------------
# Accuracy (Train) on SVHN: 94.56%, +0.53%
# Accuracy (Test) on SVHN: 90.43%, +0.15%
# -0.68% with respect to maximum of 91.10%
# --------------
# Source
# Source batch 0, epoch 45. Loss = 0.24207
# Source batch 50, epoch 45. Loss = 0.18069
# Source batch 100, epoch 45. Loss = 0.25026
# Source batch 150, epoch 45. Loss = 0.13765
# Source batch 200, epoch 45. Loss = 0.12187
# Source batch 250, epoch 45. Loss = 0.13707
# Source batch 300, epoch 45. Loss = 0.05808
# Source batch 350, epoch 45. Loss = 0.09603
# Source batch 400, epoch 45. Loss = 0.10276
# Source batch 450, epoch 45. Loss = 0.16610
# Source batch 500, epoch 45. Loss = 0.14937
# Source batch 550, epoch 45. Loss = 0.20106
# Source batch 600, epoch 45. Loss = 0.13030
# Source batch 650, epoch 45. Loss = 0.19692
# Source batch 700, epoch 45. Loss = 0.13016
# Source batch 750, epoch 45. Loss = 0.16274
# Source batch 800, epoch 45. Loss = 0.07153
# Source batch 850, epoch 45. Loss = 0.33987
# Source batch 900, epoch 45. Loss = 0.05104
# Source batch 950, epoch 45. Loss = 0.56619
# Source batch 1000, epoch 45. Loss = 0.21946
# Source batch 1050, epoch 45. Loss = 0.12501
# Source batch 1100, epoch 45. Loss = 0.23168
# --------------
# Experiment: 1/1
# Epoch 45/50 completed in 0.36612 minutes
# 21.507 minutes elapsed
# 1.85 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 46. Loss = 0.23609
# Source batch 50, epoch 46. Loss = 0.05184
# Source batch 100, epoch 46. Loss = 0.15273
# Source batch 150, epoch 46. Loss = 0.13478
# Source batch 200, epoch 46. Loss = 0.14371
# Source batch 250, epoch 46. Loss = 0.21415
# Source batch 300, epoch 46. Loss = 0.07020
# Source batch 350, epoch 46. Loss = 0.16046
# Source batch 400, epoch 46. Loss = 0.17054
# Source batch 450, epoch 46. Loss = 0.15277
# Source batch 500, epoch 46. Loss = 0.10438
# Source batch 550, epoch 46. Loss = 0.38880
# Source batch 600, epoch 46. Loss = 0.15213
# Source batch 650, epoch 46. Loss = 0.09131
# Source batch 700, epoch 46. Loss = 0.14624
# Source batch 750, epoch 46. Loss = 0.28209
# Source batch 800, epoch 46. Loss = 0.31367
# Source batch 850, epoch 46. Loss = 0.63053
# Source batch 900, epoch 46. Loss = 0.37421
# Source batch 950, epoch 46. Loss = 0.32934
# Source batch 1000, epoch 46. Loss = 0.05989
# Source batch 1050, epoch 46. Loss = 0.14295
# Source batch 1100, epoch 46. Loss = 0.25381
# --------------
# Experiment: 1/1
# Epoch 46/50 completed in 0.36694 minutes
# 21.874 minutes elapsed
# 1.48 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 47. Loss = 0.17220
# Source batch 50, epoch 47. Loss = 0.06147
# Source batch 100, epoch 47. Loss = 0.06094
# Source batch 150, epoch 47. Loss = 0.18029
# Source batch 200, epoch 47. Loss = 0.19746
# Source batch 250, epoch 47. Loss = 0.75811
# Source batch 300, epoch 47. Loss = 0.34317
# Source batch 350, epoch 47. Loss = 0.26741
# Source batch 400, epoch 47. Loss = 0.14079
# Source batch 450, epoch 47. Loss = 0.38718
# Source batch 500, epoch 47. Loss = 0.09582
# Source batch 550, epoch 47. Loss = 0.13591
# Source batch 600, epoch 47. Loss = 0.34959
# Source batch 650, epoch 47. Loss = 0.03019
# Source batch 700, epoch 47. Loss = 0.25737
# Source batch 750, epoch 47. Loss = 0.24915
# Source batch 800, epoch 47. Loss = 0.15710
# Source batch 850, epoch 47. Loss = 0.10750
# Source batch 900, epoch 47. Loss = 0.23404
# Source batch 950, epoch 47. Loss = 0.23206
# Source batch 1000, epoch 47. Loss = 0.22942
# Source batch 1050, epoch 47. Loss = 0.25204
# Source batch 1100, epoch 47. Loss = 0.46184
# --------------
# Experiment: 1/1
# Epoch 47/50 completed in 0.36432 minutes
# 22.239 minutes elapsed
# 1.11 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 48. Loss = 0.14536
# Source batch 50, epoch 48. Loss = 0.27937
# Source batch 100, epoch 48. Loss = 0.31289
# Source batch 150, epoch 48. Loss = 0.27920
# Source batch 200, epoch 48. Loss = 0.50933
# Source batch 250, epoch 48. Loss = 0.15579
# Source batch 300, epoch 48. Loss = 0.08524
# Source batch 350, epoch 48. Loss = 0.18470
# Source batch 400, epoch 48. Loss = 0.14166
# Source batch 450, epoch 48. Loss = 0.28575
# Source batch 500, epoch 48. Loss = 0.07964
# Source batch 550, epoch 48. Loss = 0.16332
# Source batch 600, epoch 48. Loss = 0.19784
# Source batch 650, epoch 48. Loss = 0.09169
# Source batch 700, epoch 48. Loss = 0.25130
# Source batch 750, epoch 48. Loss = 0.20338
# Source batch 800, epoch 48. Loss = 0.19481
# Source batch 850, epoch 48. Loss = 0.36478
# Source batch 900, epoch 48. Loss = 0.05450
# Source batch 950, epoch 48. Loss = 0.18474
# Source batch 1000, epoch 48. Loss = 0.06581
# Source batch 1050, epoch 48. Loss = 0.19967
# Source batch 1100, epoch 48. Loss = 0.19414
# --------------
# Experiment: 1/1
# Epoch 48/50 completed in 0.36456 minutes
# 22.603 minutes elapsed
# 0.74 minutes remaining
# --------------
# --------------
# Source
# Source batch 0, epoch 49. Loss = 0.21461
# Source batch 50, epoch 49. Loss = 0.16895
# Source batch 100, epoch 49. Loss = 0.18504
# Source batch 150, epoch 49. Loss = 0.27332
# Source batch 200, epoch 49. Loss = 0.13232
# Source batch 250, epoch 49. Loss = 0.44253
# Source batch 300, epoch 49. Loss = 0.32987
# Source batch 350, epoch 49. Loss = 0.33148
# Source batch 400, epoch 49. Loss = 0.12774
# Source batch 450, epoch 49. Loss = 0.25408
# Source batch 500, epoch 49. Loss = 0.14781
# Source batch 550, epoch 49. Loss = 0.19614
# Source batch 600, epoch 49. Loss = 0.09135
# Source batch 650, epoch 49. Loss = 0.27188
# Source batch 700, epoch 49. Loss = 0.29391
# Source batch 750, epoch 49. Loss = 0.16534
# Source batch 800, epoch 49. Loss = 0.17077
# Source batch 850, epoch 49. Loss = 0.13789
# Source batch 900, epoch 49. Loss = 0.14350
# Source batch 950, epoch 49. Loss = 0.14153
# Source batch 1000, epoch 49. Loss = 0.12227
# Source batch 1050, epoch 49. Loss = 0.19150
# Source batch 1100, epoch 49. Loss = 0.21491
# --------------
# Experiment: 1/1
# Epoch 49/50 completed in 0.36340 minutes
# 22.967 minutes elapsed
# 0.37 minutes remaining
# --------------
# Validation run
# --------------
# Accuracy (Train) on SVHN: 95.23%, +0.67%
# Accuracy (Test) on SVHN: 91.18%, +0.75%
# +0.07% with respect to maximum of 91.10%
# Best accuracy on source so far!
# --------------
# Source
# Source batch 0, epoch 50. Loss = 0.15295
# Source batch 50, epoch 50. Loss = 0.35598
# Source batch 100, epoch 50. Loss = 0.14330
# Source batch 150, epoch 50. Loss = 0.18554
# Source batch 200, epoch 50. Loss = 0.13417
# Source batch 250, epoch 50. Loss = 0.14636
# Source batch 300, epoch 50. Loss = 0.17608
# Source batch 350, epoch 50. Loss = 0.18754
# Source batch 400, epoch 50. Loss = 0.17790
# Source batch 450, epoch 50. Loss = 0.22905
# Source batch 500, epoch 50. Loss = 0.10638
# Source batch 550, epoch 50. Loss = 0.20408
# Source batch 600, epoch 50. Loss = 0.10580
# Source batch 650, epoch 50. Loss = 0.20736
# Source batch 700, epoch 50. Loss = 0.19933
# Source batch 750, epoch 50. Loss = 0.20553
# Source batch 800, epoch 50. Loss = 0.19685
# Source batch 850, epoch 50. Loss = 0.13195
# Source batch 900, epoch 50. Loss = 0.18323
# Source batch 950, epoch 50. Loss = 0.06561
# Source batch 1000, epoch 50. Loss = 0.20018
# Source batch 1050, epoch 50. Loss = 0.20293
# Source batch 1100, epoch 50. Loss = 0.08535
# --------------
# Experiment: 1/1
# Epoch 50/50 completed in 0.36324 minutes
# 23.702 minutes elapsed
# 0.00 minutes remaining
# --------------
# DONE!

# %%
create_zip_name(experimentRanges)
if(zipName == ""):
    zipName = "no_name"
# zipName = "Baseline" #zip name override

# For google colab, make and download experiments zip
# logsFolder = "{}.zip".format(zipName)
# !zip -r $logsFolder /logs/
# from google.colab import files
# files.download("/content/" + logsFolder)
# Out:
#   adding: logs/ (stored 0%)
#   adding: logs/SVHN-MNIST, experiment parameters: (0.7, 1024, 0.0001, 5e-06), 50 epochs.Date - 20200609-1001/ (stored 0%)
#   adding: logs/SVHN-MNIST, experiment parameters: (0.7, 1024, 0.0001, 5e-06), 50 epochs.Date - 20200609-1001/settings.txt (deflated 29%)
#   adding: logs/SVHN-MNIST, experiment parameters: (0.7, 1024, 0.0001, 5e-06), 50 epochs.Date - 20200609-1001/events.out.tfevents.1591696867.b08766c7b022.119.5.v2 (deflated 9%)
#   adding: logs/SVHN-MNIST, experiment parameters: (0.7, 1024, 0.0001, 5e-06), 50 epochs.Date - 20200609-1001/events.out.tfevents.1591696867.b08766c7b022.119.13.v2 (deflated 7%)
#   adding: logs/SVHN-MNIST, experiment parameters: (0.7, 1024, 0.0001, 5e-06), 50 epochs.Date - 20200609-1125/ (stored 0%)
#   adding: logs/SVHN-MNIST, experiment parameters: (0.7, 1024, 0.0001, 5e-06), 50 epochs.Date - 20200609-1125/settings.txt (deflated 29%)
#   adding: logs/SVHN-MNIST, experiment parameters: (0.7, 1024, 0.0001, 5e-06), 50 epochs.Date - 20200609-1125/events.out.tfevents.1591701947.b08766c7b022.119.41.v2 (deflated 75%)
#   adding: logs/SVHN-MNIST, experiment parameters: (0.7, 1024, 0.0001, 5e-06), 50 epochs.Date - 20200609-1125/events.out.tfevents.1591701947.b08766c7b022.119.49.v2 (deflated 66%)
#   adding: logs/experimentRanges.txt (deflated 11%)
